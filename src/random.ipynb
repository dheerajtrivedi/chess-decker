# %%
import pandas as pd

# Read parquet file
df = pd.read_parquet("src/train-00000-of-00003.parquet")

# Extract top 10 rows and export to Excel
df.head(10).to_excel("top_10_rows.xlsx", index=False)

print("Top 10 rows exported to top_10_rows.xlsx")
